// %% [markdown]
// // %% [markdown]
// /*
// ## JavaScript quick-start (Cell 1)
//
// JavaScript is a flexible language used for web apps, servers, and automation.
// Start with small scripts, run often, and read error messages carefully.
//
// Basic workflow:
// 1. Define small variables/functions.
// 2. Test with `console.log`.
// 3. Refactor once behavior is correct.
// */
//
//
// // %%
// /*
// Cell 2 (code): basic syntax and output
// */
// const userName = "Sam";
// const yearStarted = 2024;
// const isLearningFast = true;
//
// console.log("User:", userName);
// console.log("Started:", yearStarted);
// console.log("Learning fast:", isLearningFast);
//
//
// // %% [markdown]
// /*
// ## Good coding habits (Cell 3)
//
// - Use `const` by default; use `let` only when reassignment is needed.
// - Write descriptive names (`totalPrice` instead of `tp`).
// - Keep functions focused on one task.
// - Prefer template strings for readable output.
// */
//
//
// // %%
// /*
// Cell 4 (code): function + array processing
// */
// function greet(name) {
//     return `Hello, ${name}! Keep practicing JavaScript daily.`;
// }
//
// const topics = ["variables", "functions", "arrays", "objects"];
// const completed = topics.map((topic, index) => `${index + 1}. ${topic}`);
//
// console.log(greet(userName));
// console.log("Completed topics:");
// console.log(completed.join("\n"));
